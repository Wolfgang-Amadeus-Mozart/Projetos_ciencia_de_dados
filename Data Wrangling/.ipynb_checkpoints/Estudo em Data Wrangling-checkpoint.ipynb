# %% [markdown]
# # Estudo em Data Wrangling -
# ## Este notebook utiliza a biblioteca pandas para realizar o tratamento de uma base de dados
#
# ### Site:       https://filipedeabreu.com
#
# ### Autor:      Filipe de Abreu
#
# ### Manutenção:  Filipe de Abreu
#
# <hr>
#
# # Testado em
# ### OS: Windows 11
# ### Versão do python: 3.12.7

# %%
# Carregando os pacotes
import pandas as pd

# %%
# Carregando os datasets

dados_filmes = pd.read_csv('(5.2) Filmes Streaming.csv', sep=',')
dados_series = pd.read_csv('(5.3) Séries Streaming.csv', sep=',')

dados_filmes.info()
dados_filmes
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9515 entries, 0 to 9514
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       9515 non-null   int64
#  1   ID               9515 non-null   int64
#  2   Title            9515 non-null   object
#  3   Year             9515 non-null   int64
#  4   Age              5338 non-null   object
#  5   IMDb             9309 non-null   object
#  6   Rotten Tomatoes  9508 non-null   object
#  7   Netflix          9515 non-null   int64
#  8   Hulu             9515 non-null   int64
#  9   Prime Video      9515 non-null   int64
#  10  Disney+          9515 non-null   int64
#  11  Type             9515 non-null   int64
#  12  Directors        9104 non-null   object
#  13  Genres           9399 non-null   object
#  14  Country          9261 non-null   object
#  15  Language         9185 non-null   object
#  16  Runtime          9196 non-null   float64
# dtypes: float64(1), int64(8), object(8)
# memory usage: 1.2+ MB
#       Unnamed: 0    ID                                     Title  Year  Age  \
# 0              0     1                              The Irishman  2019  18+
# 1              1     2                                    Dangal  2016   7+
# 2              2     3  David Attenborough: A Life on Our Planet  2020   7+
# 3              3     4         Lagaan: Once Upon a Time in India  2001   7+
# 4              4     5                                      Roma  2018  18+
# ...          ...   ...                                       ...   ...  ...
# 9510        9510  9511                        Most Wanted Sharks  2020  NaN
# 9511        9511  9512             Doc McStuffins: The Doc Is In  2020  NaN
# 9512        9512  9513                     Ultimate Viking Sword  2019  NaN
# 9513        9513  9514           Hunt for the Abominable Snowman  2011  NaN
# 9514        9514  9515       Women of Impact: Changing the World  2019   7+
#
#         IMDb Rotten Tomatoes  Netflix  Hulu  Prime Video  Disney+  Type  \
# 0     7.8/10          98/100        1     0            0        0     0
# 1     8.4/10          97/100        1     0            0        0     0
# 2     9.0/10          95/100        1     0            0        0     0
# 3     8.1/10          94/100        1     0            0        0     0
# 4     7.7/10          94/100        1     0            0        0     0
# ...      ...             ...      ...   ...          ...      ...   ...
# 9510     NaN          14/100        0     0            0        1     0
# 9511     NaN          13/100        0     0            0        1     0
# 9512     NaN          13/100        0     0            0        1     0
# 9513     NaN          10/100        0     0            0        1     0
# 9514     NaN          10/100        0     0            0        1     0
#
#                                               Directors  \
# 0                                       Martin Scorsese
# 1                                         Nitesh Tiwari
# 2     Alastair Fothergill,Jonathan Hughes,Keith Scholey
# 3                                    Ashutosh Gowariker
# 4                                                   NaN
# ...                                                 ...
# 9510                                                NaN
# 9511                             Chris Anthony Hamilton
# 9512                                                NaN
# 9513                                         Dan Oliver
# 9514                                          Lisa Feit
#
#                                 Genres  \
# 0                Biography,Crime,Drama
# 1         Action,Biography,Drama,Sport
# 2                Documentary,Biography
# 3                  Drama,Musical,Sport
# 4     Action,Drama,History,Romance,War
# ...                                ...
# 9510                  Crime,Reality-TV
# 9511                         Animation
# 9512                               NaN
# 9513                     Drama,History
# 9514                       Documentary
#
#                                                 Country  \
# 0                                         United States
# 1     India,United States,United Kingdom,Australia,K...
# 2                                        United Kingdom
# 3                                  India,United Kingdom
# 4                          United Kingdom,United States
# ...                                                 ...
# 9510                                      United States
# 9511                                      United States
# 9512                                      United States
# 9513                                                NaN
# 9514                                      United States
#
#                                   Language  Runtime
# 0     English,Italian,Latin,Spanish,German    209.0
# 1                            Hindi,English    161.0
# 2                                  English     83.0
# 3                            Hindi,English    224.0
# 4                                  English     52.0
# ...                                    ...      ...
# 9510                         Greek,English      NaN
# 9511                               English     23.0
# 9512                                   NaN      NaN
# 9513                                   NaN      NaN
# 9514                               English      NaN
#
# [9515 rows x 17 columns]

# %%
dados_filmes.info()
dados_series
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9515 entries, 0 to 9514
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       9515 non-null   int64
#  1   ID               9515 non-null   int64
#  2   Title            9515 non-null   object
#  3   Year             9515 non-null   int64
#  4   Age              5338 non-null   object
#  5   IMDb             9309 non-null   object
#  6   Rotten Tomatoes  9508 non-null   object
#  7   Netflix          9515 non-null   int64
#  8   Hulu             9515 non-null   int64
#  9   Prime Video      9515 non-null   int64
#  10  Disney+          9515 non-null   int64
#  11  Type             9515 non-null   int64
#  12  Directors        9104 non-null   object
#  13  Genres           9399 non-null   object
#  14  Country          9261 non-null   object
#  15  Language         9185 non-null   object
#  16  Runtime          9196 non-null   float64
# dtypes: float64(1), int64(8), object(8)
# memory usage: 1.2+ MB
#       Unnamed: 0    ID                                  Title  Year  Age  \
# 0              0     1                           Breaking Bad  2008  18+
# 1              1     2                        Stranger Things  2016  16+
# 2              2     3                        Attack on Titan  2013  18+
# 3              3     4                       Better Call Saul  2015  18+
# 4              4     5                                   Dark  2017  16+
# ...          ...   ...                                    ...   ...  ...
# 5363        5363  5713                       Paradise Islands  2017  NaN
# 5364        5364  5714                         Mexico Untamed  2018  NaN
# 5365        5365  5715                  Wild Centeral America  2020  NaN
# 5366        5366  5716                            Wild Russia  2018  NaN
# 5367        5367  5717  Fearless Adventures with Jack Randall  2018  NaN
#
#         IMDb Rotten Tomatoes  Netflix  Hulu  Prime Video  Disney+  Type
# 0     9.4/10         100/100        1     0            0        0     1
# 1     8.7/10          96/100        1     0            0        0     1
# 2     9.0/10          95/100        1     1            0        0     1
# 3     8.8/10          94/100        1     0            0        0     1
# 4     8.8/10          93/100        1     0            0        0     1
# ...      ...             ...      ...   ...          ...      ...   ...
# 5363     NaN          10/100        0     0            0        1     1
# 5364     NaN          10/100        0     0            0        1     1
# 5365     NaN          10/100        0     0            0        1     1
# 5366     NaN          10/100        0     0            0        1     1
# 5367     NaN          10/100        0     0            0        1     1
#
# [5368 rows x 12 columns]

# %%
#Verificou-se que existem variaveis diferentes em ambos os datasets, criando dataframe para comparação das colunas
df_columns = pd.DataFrame({
    'Filmes': dados_filmes.columns,         
})

df_columns_series = pd.DataFrame({
    'Series': dados_series.columns,         
})

new = pd.concat([df_columns, df_columns_series], axis=1)
new
# Out:
#              Filmes           Series
# 0        Unnamed: 0       Unnamed: 0
# 1                ID               ID
# 2             Title            Title
# 3              Year             Year
# 4               Age              Age
# 5              IMDb             IMDb
# 6   Rotten Tomatoes  Rotten Tomatoes
# 7           Netflix          Netflix
# 8              Hulu             Hulu
# 9       Prime Video      Prime Video
# 10          Disney+          Disney+
# 11             Type             Type
# 12        Directors              NaN
# 13           Genres              NaN
# 14          Country              NaN
# 15         Language              NaN
# 16          Runtime              NaN

# %%
#Verificando a quantidade de variaveis e cada dataframe
print(f'''
{dados_filmes.shape[1]}
{dados_series.shape[1]}
'''
)
# Out:
# 17
# 12

# %%
# Selecionado colunas e realizando a junção dos bancos de dados

# Os dois datasets têm estruturas semelhantes quanto às variáveis
# Porém, o dataset sobre filmes tem colunas a mais
# Vamos fazer uma rápida organização dos datasets e juntá-los

# Seleção das variáveis de interesse
dados_filmes = dados_filmes.iloc[:,0:12]

# Junção dos dados
dados_completo = pd.concat([dados_filmes, dados_series], ignore_index=True)

# Remoção da variável Unnamed: 0
dados_completo.drop(columns=['Unnamed: 0'], inplace=True)

dados_completo
# Out:
#          ID                                     Title  Year  Age    IMDb  \
# 0         1                              The Irishman  2019  18+  7.8/10
# 1         2                                    Dangal  2016   7+  8.4/10
# 2         3  David Attenborough: A Life on Our Planet  2020   7+  9.0/10
# 3         4         Lagaan: Once Upon a Time in India  2001   7+  8.1/10
# 4         5                                      Roma  2018  18+  7.7/10
# ...     ...                                       ...   ...  ...     ...
# 14878  5713                          Paradise Islands  2017  NaN     NaN
# 14879  5714                            Mexico Untamed  2018  NaN     NaN
# 14880  5715                     Wild Centeral America  2020  NaN     NaN
# 14881  5716                               Wild Russia  2018  NaN     NaN
# 14882  5717     Fearless Adventures with Jack Randall  2018  NaN     NaN
#
#       Rotten Tomatoes  Netflix  Hulu  Prime Video  Disney+  Type
# 0              98/100        1     0            0        0     0
# 1              97/100        1     0            0        0     0
# 2              95/100        1     0            0        0     0
# 3              94/100        1     0            0        0     0
# 4              94/100        1     0            0        0     0
# ...               ...      ...   ...          ...      ...   ...
# 14878          10/100        0     0            0        1     1
# 14879          10/100        0     0            0        1     1
# 14880          10/100        0     0            0        1     1
# 14881          10/100        0     0            0        1     1
# 14882          10/100        0     0            0        1     1
#
# [14883 rows x 11 columns]

# %% [markdown]
# Como o valor da variavel 'type' para filmes é 0 e para séries é 1, fica fácil identificar e extrair informações independente se for série ou filme

# %%
# Extrair as notas do texto

# Extrair as notas e Ajustar a string e transformar para float
dados_completo['Ajuste_IMDB'] = dados_completo['IMDb'].str.slice(0, 3).astype('float')
dados_completo['Ajuste_Rotten'] = dados_completo['Rotten Tomatoes'].str.slice(0, 2).astype('float')

dados_completo
# Out:
#          ID                                     Title  Year  Age    IMDb  \
# 0         1                              The Irishman  2019  18+  7.8/10
# 1         2                                    Dangal  2016   7+  8.4/10
# 2         3  David Attenborough: A Life on Our Planet  2020   7+  9.0/10
# 3         4         Lagaan: Once Upon a Time in India  2001   7+  8.1/10
# 4         5                                      Roma  2018  18+  7.7/10
# ...     ...                                       ...   ...  ...     ...
# 14878  5713                          Paradise Islands  2017  NaN     NaN
# 14879  5714                            Mexico Untamed  2018  NaN     NaN
# 14880  5715                     Wild Centeral America  2020  NaN     NaN
# 14881  5716                               Wild Russia  2018  NaN     NaN
# 14882  5717     Fearless Adventures with Jack Randall  2018  NaN     NaN
#
#       Rotten Tomatoes  Netflix  Hulu  Prime Video  Disney+  Type  Ajuste_IMDB  \
# 0              98/100        1     0            0        0     0          7.8
# 1              97/100        1     0            0        0     0          8.4
# 2              95/100        1     0            0        0     0          9.0
# 3              94/100        1     0            0        0     0          8.1
# 4              94/100        1     0            0        0     0          7.7
# ...               ...      ...   ...          ...      ...   ...          ...
# 14878          10/100        0     0            0        1     1          NaN
# 14879          10/100        0     0            0        1     1          NaN
# 14880          10/100        0     0            0        1     1          NaN
# 14881          10/100        0     0            0        1     1          NaN
# 14882          10/100        0     0            0        1     1          NaN
#
#        Ajuste_Rotten
# 0               98.0
# 1               97.0
# 2               95.0
# 3               94.0
# 4               94.0
# ...              ...
# 14878           10.0
# 14879           10.0
# 14880           10.0
# 14881           10.0
# 14882           10.0
#
# [14883 rows x 13 columns]

# %%
# Gerando estatísticas sobre as notas

# Atribuindo labels
muda_numeros = {0: 'filme', 1: 'série'}
dados_completo = dados_completo.assign(tipo = dados_completo.Type.map(muda_numeros))

# Agrupando o dataset
descritivas = dados_completo.groupby(['tipo'])

# Gerando estatísticas por variável
descritivas['Ajuste_IMDB'].describe().T
descritivas['Ajuste_Rotten'].describe().T
# Out:
# tipo         filme        série
# count  9508.000000  5368.000000
# mean     53.545015    47.186848
# std      13.197673    19.542378
# min      10.000000    10.000000
# 25%      44.000000    36.000000
# 50%      52.000000    48.000000
# 75%      62.000000    60.000000
# max      98.000000    96.000000

# %%
# Criando um indicador dos "melhores" filmes e séries

# Separando o banco de dados
melhores_series = dados_completo[dados_completo['tipo']=='série']
melhores_filmes = dados_completo[dados_completo['tipo']=='filme']

# %%
# Séries

# Irei identificar aqueles que estão com melhores notas nas duas avaliações utilizando o percentil de 95
melhores_series[['Ajuste_IMDB', 'Ajuste_Rotten']].quantile(0.95)
# Out:
# Ajuste_IMDB       8.5
# Ajuste_Rotten    79.0
# Name: 0.95, dtype: float64

# %%
# Gerando os dados

melhores_series = melhores_series.assign(Categ_IMDB = pd.qcut(melhores_series.Ajuste_IMDB,
                                                              q=[0, 0.95, 1.0],
                                                              labels=['menores',
                                                                      'maiores']))

melhores_series = melhores_series.assign(Categ_Rotten = pd.qcut(melhores_series.Ajuste_Rotten,
                                                                q=[0, 0.95, 1.0],
                                                                labels=['menores',
                                                                        'maiores']))

melhores_series = melhores_series[(melhores_series['Categ_IMDB']=='maiores') &
                                  (melhores_series['Categ_Rotten']=='maiores')].sort_values(['Ajuste_Rotten', 'Ajuste_IMDB'], ascending=False)


melhores_series
# Out:
#          ID                       Title  Year  Age    IMDb Rotten Tomatoes  \
# 9516      2             Stranger Things  2016  16+  8.7/10          96/100
# 9517      3             Attack on Titan  2013  18+  9.0/10          95/100
# 9518      4            Better Call Saul  2015  18+  8.8/10          94/100
# 14573  5377             The Mandalorian  2019  16+  8.8/10          94/100
# 9520      6  Avatar: The Last Airbender  2005   7+  9.3/10          93/100
# ...     ...                         ...   ...  ...     ...             ...
# 11529  2040                   Peep Show  2003  18+  8.6/10          81/100
# 11541  2057                Cowboy Bebop  1998  16+  8.9/10          80/100
# 9630    116              Anne with an E  2017  all  8.7/10          80/100
# 9624    110                Sacred Games  2018  18+  8.6/10          80/100
# 12993  3634                   Endeavour  2013  16+  8.6/10          80/100
#
#        Netflix  Hulu  Prime Video  Disney+  Type  Ajuste_IMDB  Ajuste_Rotten  \
# 9516         1     0            0        0     1          8.7           96.0
# 9517         1     1            0        0     1          9.0           95.0
# 9518         1     0            0        0     1          8.8           94.0
# 14573        0     0            0        1     1          8.8           94.0
# 9520         1     0            1        0     1          9.3           93.0
# ...        ...   ...          ...      ...   ...          ...            ...
# 11529        0     1            1        0     1          8.6           81.0
# 11541        0     1            0        0     1          8.9           80.0
# 9630         1     0            0        0     1          8.7           80.0
# 9624         1     0            0        0     1          8.6           80.0
# 12993        0     0            1        0     1          8.6           80.0
#
#         tipo Categ_IMDB Categ_Rotten
# 9516   série    maiores      maiores
# 9517   série    maiores      maiores
# 9518   série    maiores      maiores
# 14573  série    maiores      maiores
# 9520   série    maiores      maiores
# ...      ...        ...          ...
# 11529  série    maiores      maiores
# 11541  série    maiores      maiores
# 9630   série    maiores      maiores
# 9624   série    maiores      maiores
# 12993  série    maiores      maiores
#
# [71 rows x 16 columns]

# %%
# Filmes

# Vamos identificar aqueles que estão com melhores notas nas duas avaliações
# Vamos usar o percentil 95 das notas como referência
melhores_filmes[['Ajuste_IMDB', 'Ajuste_Rotten']].quantile(0.95)

# Gerando os dados

melhores_filmes = melhores_filmes.assign(Categ_IMDB = pd.qcut(melhores_filmes.Ajuste_IMDB,
                                                              q=[0, 0.95, 1.0],
                                                              labels=['menores',
                                                                      'maiores']))

melhores_filmes = melhores_filmes.assign(Categ_Rotten = pd.qcut(melhores_filmes.Ajuste_Rotten,
                                                                q=[0, 0.95, 1.0],
                                                                labels=['menores',
                                                                        'maiores']))

melhores_filmes = melhores_filmes[(melhores_filmes['Categ_IMDB']=='maiores') &
                                  (melhores_filmes['Categ_Rotten']=='maiores')].sort_values(['Ajuste_IMDB', 'Ajuste_Rotten'], ascending=False)


melhores_filmes.head(30)
# Out:
#         ID                                        Title  Year  Age    IMDb  \
# 2        3     David Attenborough: A Life on Our Planet  2020   7+  9.0/10
# 3695  3696                              The Dark Knight  2008  13+  9.0/10
# 4703  4704                                   Fight Club  1999  18+  8.8/10
# 138    139                           Bo Burnham: Inside  2021  18+  8.8/10
# 8619  8620           Star Wars: The Empire Strikes Back  1980   7+  8.7/10
# 8618  8619                        Star Wars: A New Hope  1977   7+  8.6/10
# 3697  3698                                     Parasite  2019  18+  8.6/10
# 4722  4723                        It's a Wonderful Life  1946   7+  8.6/10
# 18      19                                 Black Friday  2004  18+  8.5/10
# 24      25                                 The Departed  2006  18+  8.5/10
# 26      27                   Terminator 2: Judgment Day  1991  18+  8.5/10
# 8622  8623                                The Lion King  1994  all  8.5/10
# 38      39                             The Intouchables  2011   7+  8.5/10
# 44      45                 No Direction Home: Bob Dylan  2005  all  8.5/10
# 55      56                                  The Pianist  2002  18+  8.5/10
# 4715  4716                                     Mahanati  2018   7+  8.5/10
# 4717  4718                                  Rear Window  1954   7+  8.5/10
# 77      78              Dave Chappelle: Sticks & Stones  2019  18+  8.5/10
# 3716  3717                 Once Upon a Time in the West  1968  13+  8.5/10
# 114    115                      Springsteen On Broadway  2018  NaN  8.5/10
# 1        2                                       Dangal  2016   7+  8.4/10
# 8616  8617                            Avengers: Endgame  2019  13+  8.4/10
# 8617  8618                       Avengers: Infinity War  2018  13+  8.4/10
# 25      26  Winter on Fire: Ukraine's Fight for Freedom  2015  16+  8.4/10
# 28      29                             Django Unchained  2012  18+  8.4/10
# 4709  4710                                        Alien  1979  18+  8.4/10
# 8623  8624                                       WALL·E  2008  all  8.4/10
# 47      48                                 Super Deluxe  2019  18+  8.4/10
# 8631  8632                                         Coco  2017   7+  8.4/10
# 56      57                                     3 Idiots  2009  13+  8.4/10
#
#      Rotten Tomatoes  Netflix  Hulu  Prime Video  Disney+  Type  Ajuste_IMDB  \
# 2             95/100        1     0            0        0     0          9.0
# 3695          94/100        0     1            0        0     0          9.0
# 4703          93/100        0     0            1        0     0          8.8
# 138           81/100        1     0            0        0     0          8.8
# 8619          89/100        0     0            0        1     0          8.7
# 8618          89/100        0     0            0        1     0          8.6
# 3697          88/100        0     1            0        0     0          8.6
# 4722          84/100        0     0            1        0     0          8.6
# 18            90/100        1     0            0        0     0          8.5
# 24            89/100        1     0            0        0     0          8.5
# 26            89/100        1     0            0        0     0          8.5
# 8622          89/100        0     0            0        1     0          8.5
# 38            88/100        1     0            0        0     0          8.5
# 44            87/100        1     0            0        0     0          8.5
# 55            86/100        1     0            0        0     0          8.5
# 4715          86/100        0     0            1        0     0          8.5
# 4717          85/100        0     0            1        0     0          8.5
# 77            84/100        1     0            0        0     0          8.5
# 3716          83/100        0     1            0        0     0          8.5
# 114           82/100        1     0            0        0     0          8.5
# 1             97/100        1     0            0        0     0          8.4
# 8616          90/100        0     0            0        1     0          8.4
# 8617          90/100        0     0            0        1     0          8.4
# 25            89/100        1     0            0        0     0          8.4
# 28            89/100        1     0            0        0     0          8.4
# 4709          88/100        0     0            1        0     0          8.4
# 8623          88/100        0     0            0        1     0          8.4
# 47            87/100        1     0            0        0     0          8.4
# 8631          87/100        0     0            0        1     0          8.4
# 56            86/100        1     0            0        0     0          8.4
#
#       Ajuste_Rotten   tipo Categ_IMDB Categ_Rotten
# 2              95.0  filme    maiores      maiores
# 3695           94.0  filme    maiores      maiores
# 4703           93.0  filme    maiores      maiores
# 138            81.0  filme    maiores      maiores
# 8619           89.0  filme    maiores      maiores
# 8618           89.0  filme    maiores      maiores
# 3697           88.0  filme    maiores      maiores
# 4722           84.0  filme    maiores      maiores
# 18             90.0  filme    maiores      maiores
# 24             89.0  filme    maiores      maiores
# 26             89.0  filme    maiores      maiores
# 8622           89.0  filme    maiores      maiores
# 38             88.0  filme    maiores      maiores
# 44             87.0  filme    maiores      maiores
# 55             86.0  filme    maiores      maiores
# 4715           86.0  filme    maiores      maiores
# 4717           85.0  filme    maiores      maiores
# 77             84.0  filme    maiores      maiores
# 3716           83.0  filme    maiores      maiores
# 114            82.0  filme    maiores      maiores
# 1              97.0  filme    maiores      maiores
# 8616           90.0  filme    maiores      maiores
# 8617           90.0  filme    maiores      maiores
# 25             89.0  filme    maiores      maiores
# 28             89.0  filme    maiores      maiores
# 4709           88.0  filme    maiores      maiores
# 8623           88.0  filme    maiores      maiores
# 47             87.0  filme    maiores      maiores
# 8631           87.0  filme    maiores      maiores
# 56             86.0  filme    maiores      maiores
